# %%
from random import shuffle, randrange
import random

greeting = ['안녕하세요', '실례하겠습니다', '저기요', '말씀 좀 여쭐께요', '<SILENCE>']

collect = ["처방전 받으러 왔습니다", "처방전 받으로 왔는데요",
            "처방전 주세요", "처방전 준비 됬다고 하던데요",
            "저방전 준비 됬나요", 
            "의사선생님이 처방전 준비 됬다고 했어요"]

check_in = ["예약 확인 좀 부탁드립니다",
            "전에 예약했는데 확인 부탁 좀 드릴께요",
            "의사선생님 예약 확인 부탁 드릴께요",
            "오늘 예약 있어요"]

# overturn = ["아참 오후 3시 였어요", "죄송해요 오후 3시 였던거 같아요"]

find = ["화장실 좀 쓰고 싶습니다", "화장실이 어디에 있나요",
        "화장실 좀 쓰고 싶은데 어디에 있는지 알려주세요",
        "주변에 화장실 있나요", "근처 화장실이 어디에 있나요", 
        "화장실 좀 써도 되나요", "지금 사용 가능한 화장실 있나요"]

ask = ["얼마나 기다려야 되죠",
        "얼마나 기다려야 하나요",
        "의사선생님 지금 안계시나요", "많이 기다려야 되나요", "얼마나 기다려야 됩니까"]

addition = ["<SILENCE>", "좋아요", "좋습니다", "고맙습니다", "완벽해요"]

say_name = ["황의준", "제 이름은 황의준입니다", "내 이름은 황의준이야", "내 이름은 황의준이에요"]

say_time = ["오후 4시요", "오후 4시입니다", "오후 4시야", "오후 4시에 약속이 있습니다", "오후 4시에 예약이 잡혀 있어요"]

say_address = ["우리집 주소는 조례동 123 입니다", "조례동 123 이야", "조례동 123 입니다", "조례동 123 에 삽니다"]

say_dont_know = ["기억이 안나요", "모르겠어요", "몰라", "기억이 안나네요" "몰라요"]

say_no = ["괜찮아요", "괜찮습니다", "아니요", "아뇨"]

########################## responses ###################################################
resp_greeting = '안녕하세요, 저는 리셉션 로봇 나오에요. 어떻게 도와드릴까요?'

resp_askName = '알겠습니다. 이름을 알려주세요.'

resp_askAddress = '감사합니다 황의준 님. 주소를 알려주시겠어요?'

resp_collect_done = "api_call 처방전 황의준 조례동 123"

resp_doctocName = "오늘 만나려는 의사선생님 성함은 어떻게 되시나요?"

resp_docName = "네 알겠습니다. 오늘 보려는 의사선생님 성함을 알려주세요."

resp_ask_time = "알겠습니다 황의준 님, 오늘 약속시간은 어떻게 되시나요?"

resp_check_in_done = "api_call 예약 황의준 조례동 123 4시"

resp_ask = "api_call 대기시간 황의준 조례동 123 4시"

resp_find = "api_call 위치 화장실"

resp_help = "제가 도와드릴게 있을까요?"

resp_bye = "좋은 하루 보내시길 바라겠습니다. 황의준 님"

resp_bye_no_name = "좋은 하루 보내세요."

resp_check = "잠시만 기다려주세요."


gap = '	'

# %%
# ['greeting', 'collect', 'check_in']
def scenario_1():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    script += random.choice(collect) + gap + resp_askName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(check_in) + gap + resp_ask_time + "\n"
    script += random.choice(say_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

# ['greeting', 'check_in', 'ask', collect']
def scenario_2():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    script += random.choice(check_in) + gap + resp_askName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_ask_time + "\n"
    script += random.choice(say_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script


# ['greeting', 'collect', check_in']
def scenario_3():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    script += random.choice(collect) + gap + resp_askName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(check_in) + gap + resp_ask_time + "\n"
    script += random.choice(say_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script


# ['greeting', check_in', collect']
def scenario_4():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    script += random.choice(check_in) + gap + resp_askName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_ask_time + "\n"
    script += random.choice(say_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

# ['greeting', 'check_in', 'ask', 'collect', 'find']
def scenario_5():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    script += random.choice(check_in) + gap + resp_askName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_ask_time + "\n"
    script += random.choice(say_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

# ['greeting', 'collect', 'check_in', 'ask', 'find']
def scenario_6():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    script += random.choice(collect) + gap + resp_askName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(check_in) + gap + resp_ask_time + "\n"
    script += random.choice(say_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

# # ['greeting', 'find']
# def scenario_7():
#     script = ''
#     script += random.choice(greeting) + gap + resp_greeting + "\n"
#     script += random.choice(find) + gap + resp_find + "\n"
#     script += random.choice(addition) + gap + resp_bye_no_name + "\n"
#     script += "\n"
    
#     return script


# # ['greeting', collect', 'check_in', 'overturn', 'ask', 'find']
# def scenario_8():
#     script = ''
#     script += random.choice(greeting) + gap + resp_greeting + "\n"
#     script += random.choice(collect) + gap + resp_askName + "\n"
#     script += random.choice(say_name) + gap + resp_askAddress + "\n"
#     script += random.choice(say_address) + gap + resp_collect_done + "\n"
#     script += random.choice(addition) + gap + resp_help + "\n"
#     script += random.choice(check_in) + gap + resp_ask_time + "\n"
#     script += random.choice(say_time) + gap + resp_doctocName + "\n"
#     script += random.choice(overturn) + gap + resp_docName + "\n"
#     script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
#     script += random.choice(addition) + gap + resp_help + "\n"
#     script += random.choice(ask) + gap + resp_ask + "\n"
#     script += random.choice(addition) + gap + resp_help + "\n"
#     script += random.choice(find) + gap + resp_find + "\n"
#     script += random.choice(addition) + gap + resp_bye + "\n"
#     script += "\n"
    
#     return script

# %%
checkin_with_name = ["안녕하세요, 제 이름은 황의준 이구 오늘 의사선생님과 약속이 잡혀있습니다",
                    "저는 황의준이고 오늘 예약이 잡혀있는데요"]
checkin_with_all = ["안녕하세요, 제 이름은 황의준이고 주소는 조례동 123 입니다 오늘 예약이 잡혀있어요",
                   "저는 황의준이고 주소는 조례동 123 입니다 오늘 의사선생님과 약속이 잡혀있습니다"]

collect_with_name = ["제 이름은 황의준 이구 처방전 받으러 왔습니다", "제 이름은 황의준 이구 처방전 받으로 왔는데요",
            "제 이름은 황의준 이구 처방전 주세요", "제 이름은 황의준 이구 처방전 준비 됬다고 하던데요",
            "제 이름은 황의준 이구 처방전 준비 됬나요", 
            "제 이름은 황의준 이구 의사선생님이 처방전 준비 됬다고 했어요"]
checkin_with_time = ["제 이름은 황의준 이구 오후 4시에 약속이 있습니다", "제 이름은 황의준 이구 오후 4시에 예약이 잡혀 있어요"]
collect_with_all = ["제 이름은 황의준 이구 주소는 조례동 123 입니다 처방전 받으러 왔습니다", "제 이름은 황의준 이구 주소는 조례동 123 입니다 처방전 받으로 왔는데요",
            "제 이름은 황의준 이구 주소는 조례동 123 입니다 처방전 주세요", "제 이름은 황의준 이구 주소는 조례동 123 입니다 처방전 준비 됬다고 하던데요",
            "제 이름은 황의준 이구 주소는 조례동 123 입니다 처방전 준비 됬나요", 
            "제 이름은 황의준 이구 주소는 조례동 123 입니다 의사선생님이 처방전 준비 됬다고 했어요"]

# %%
def d_1():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # check in
    script += random.choice(checkin_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time 
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_2():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # check in
    script += random.choice(checkin_with_all) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time 
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
     # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_3():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # collect prescription
    script += random.choice(collect_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_4():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # collect prescription
    script += random.choice(collect_with_all) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(check_in) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_5():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect prescription
    script += random.choice(collect_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
     # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # check in
    script += random.choice(checkin_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time 
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_2():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # check in
    script += random.choice(checkin_with_all) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time 
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
     # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_3():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # collect prescription
    script += random.choice(collect_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_4():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # collect prescription
    script += random.choice(collect_with_all) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(check_in) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
def d_5():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect prescription
    script += random.choice(collect_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
     # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

def d_6():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

def d_7():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # check in
    script += random.choice(checkin_with_all) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time 
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
     # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

def d_8():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # collect prescription
    script += random.choice(collect_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script
    
    return script

def d_6():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

def d_7():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # check in
    script += random.choice(checkin_with_all) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # collect presciption
    script += random.choice(collect) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time 
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
     # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

def d_8():
    script = ''
    script += random.choice(greeting) + gap + resp_greeting + "\n"
    # collect prescription
    script += random.choice(collect_with_name) + gap + resp_askAddress + "\n"
    script += random.choice(say_address) + gap + resp_collect_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # check in
    script += random.choice(checkin_with_time) + gap + resp_doctocName + "\n"
    script += random.choice(say_dont_know) + gap + resp_check_in_done + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask loaction
    script += random.choice(find) + gap + resp_find + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # ask waiting time
    script += random.choice(ask) + gap + resp_ask + "\n"
    script += random.choice(addition) + gap + resp_help + "\n"
    # close
    script += random.choice(say_no) + gap + resp_bye + "\n"
    script += "\n"
    
    return script

# %%
print(scenario_4())
# Out:
# 실례하겠습니다	안녕하세요, 저는 리셉션 로봇 나오에요. 어떻게 도와드릴까요?
# 의사선생님 예약 확인 부탁 드릴께요	알겠습니다. 이름을 알려주세요.
# 황의준	감사합니다 황의준 님. 주소를 알려주시겠어요?
# 조례동 123 에 삽니다	알겠습니다 황의준 님, 오늘 약속시간은 어떻게 되시나요?
# 오후 4시에 약속이 있습니다	오늘 만나려는 의사선생님 성함은 어떻게 되시나요?
# 기억이 안나네요몰라요	api_call 예약 황의준 조례동 123 4시
# 좋습니다	제가 도와드릴게 있을까요?
# 처방전 받으로 왔는데요	api_call 처방전 황의준 조례동 123
# 좋아요	제가 도와드릴게 있을까요?
# 괜찮아요	좋은 하루 보내시길 바라겠습니다. 황의준 님

# %%
def generate_dialog():
    with open('reception_kor.txt', 'w') as f:
        for i in range(50):
            f.write(scenario_1())
            f.write(scenario_2())
            f.write(scenario_3())
            f.write(scenario_4())
            f.write(scenario_5())      
            f.write(scenario_6())
            f.write(d_1())
            f.write(d_2())
            f.write(d_3())
            f.write(d_4())
            f.write(d_5())
            f.write(d_6())
    #             f.write(d_7())
    #             f.write(d_8())

# %%
generate_dialog()
